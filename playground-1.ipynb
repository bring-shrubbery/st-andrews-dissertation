# %%
import matplotlib.pyplot as plt
import pydicom
import numpy as np
import imageio
from sklearn.preprocessing import normalize

# %%
DATAPATH = "/cs/scratch/as521/data/" # Contains 'medium-polyps' and 'large-polyps' directories
LARGE_POLYPS_DIR = "large-polyps/"
MEDIUM_POLYPS_DIR = "medium-polyps/"

# %%
large_polyps_image = "1.3.6.1.4.1.9328.50.4.0040"

# %%
IMAGE_PATH = "/cs/scratch/as521/data/large-polyps/1.3.6.1.4.1.9328.50.4.0040/01-01-2000-1-Abdomen01ACRINColonographySupine-42393/4.000000-Supine Colo.  1.0  B30f-42394/"

# %%
image_paths = []
for i in range(1, 525):
    image_paths.append("1-"+str(i).rjust(3, '0')+".dcm")

# %%
data = []

for p in image_paths:
    # Create full image path
    image_path = IMAGE_PATH + p
    
    # Load image
    image_data = pydicom.dcmread(image_path)
    data.append(image_data.pixel_array)

# %%
# if 'PixelData' in dataset:
#     rows = int(dataset.Rows)
#     cols = int(dataset.Columns)
    
#     print(f"Rows: {rows}, Columns: {cols}")

# %%
plt.imshow(data[500], cmap=plt.cm.bone, vmin=0, vmax=2500)

# %%
for i in range(len(data)):
    plt.imsave("./animation/{}.jpg".format(i), data[i], cmap=plt.cm.bone, vmin=0, vmax=2500)

# %%
lds = data
for i in range(len(data)):
    lds[i] = data[i].astype(np.uint8)

# %%
for i in range(len(data)):
    lds[i] /= 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-6cd06e3941f7> in <module>
#       1 for i in range(len(data)):
# ----> 2     lds[i] /= 2
#
# TypeError: No loop matching the specified signature and casting was found for ufunc true_divide

# %%
#lds

# %%
imageio.mimsave('./test.gif', lds)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
