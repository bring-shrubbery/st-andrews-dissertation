# %%
from src.loading import loadLargePolypImages

# %%
loadLargePolypImages('/cs/scratch/as521/data')
# Out:
# /cs/home/as521/Desktop/st-andrews-dissertation/src/../features/large_polyps.csv
# ['5.000000-Prone Colo   1.0  B30f-42920', '4.000000-Supine Colo.  1.0  B30f-42394']
# ['5.000000-Prone Colo   1.0  B30f-42920', '4.000000-Supine Colo.  1.0  B30f-42394']
# ['5.000000-Prone Colo   1.0  B30f-42920', '4.000000-Supine Colo.  1.0  B30f-42394']
# ['5.000000-Prone Colo   1.0  B30f-42920', '4.000000-Supine Colo.  1.0  B30f-42394']
# ['3.000000-Recon 2 ABD PEL WITHOUT - SUPI-14781', '6.000000-Recon 2 ABD PEL WITHOUT - PRON-15297', '1.000000-SCOUTS-14777', '4.000000-SCOUTS-15293']
# ['3.000000-Recon 2 ABD PEL WITHOUT - SUPI-14781', '6.000000-Recon 2 ABD PEL WITHOUT - PRON-15297', '1.000000-SCOUTS-14777', '4.000000-SCOUTS-15293']
# ['3.000000-Recon 2 ABD PEL WITHOUT - SUPI-14781', '6.000000-Recon 2 ABD PEL WITHOUT - PRON-15297', '1.000000-SCOUTS-14777', '4.000000-SCOUTS-15293']
# ...
